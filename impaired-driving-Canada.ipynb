# %% [markdown]
# # Impaired Driving Across Canada

# %% [markdown]
# Data set analysis. Data from Open Edmonton Data Portal

# %% [markdown]
# ### Common Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading in the Dataset

# %%
path = 'datasets/Impaired_Driving_Across_Canada.csv'

# %%
df = pd.read_csv(path, index_col = 'Police Jurisdiction')

# %%
df.head(2)
# Out:
#                        1998    1999    2000    2001    2002    2003    2004  \
# Police Jurisdiction
# St Johns, NL         202.70  181.57  202.20  206.41  171.58  180.09  170.02
# Halifax, NS          209.54  233.36  177.45  192.10  181.10  170.26  171.93
#
#                        2005    2006    2007   ...      2009    2010    2011  \
# Police Jurisdiction                           ...
# St Johns, NL         147.58  161.78  303.70   ...    420.04  458.05  528.58
# Halifax, NS          172.33  197.36  265.72   ...    255.29  271.19  276.07
#
#                        2012    2013    2014    2015    2016    2017    2018
# Police Jurisdiction
# St Johns, NL         546.16  541.33  483.14  410.30  394.52  369.31  286.14
# Halifax, NS          270.77  232.23  241.98  222.52  220.77  221.82  208.36
#
# [2 rows x 21 columns]

# %%
data = df.transpose()

# %%
data.head()
# Out:
# Police Jurisdiction  St Johns, NL  Halifax, NS  Moncton, NB  Saint John, NB  \
# 1998                       202.70       209.54          NaN          348.86
# 1999                       181.57       233.36          NaN          355.88
# 2000                       202.20       177.45          NaN          367.25
# 2001                       206.41       192.10          NaN          254.73
# 2002                       171.58       181.10          NaN          219.48
#
# Police Jurisdiction  Saguenay, QB  Quebec, QB  Sherbrooke, QB  \
# 1998                       343.57      238.59          276.28
# 1999                       352.64      239.98          208.03
# 2000                       275.73      216.86          238.32
# 2001                       249.33      207.54          203.15
# 2002                       226.84      236.31          220.05
#
# Police Jurisdiction  Trois-Rivieres, QB  Montreal, QB  Ottawa-Gateneau, ON/QB  \
# ...

# %% [markdown]
# Maybe let's go by province? Or probably Region. Maybe make sublplots of all the regions

# %%
#pd.Series(data.columns)

# %%
data.columns[4:9]
# Out:
# Index(['Saguenay, QB', 'Quebec, QB', 'Sherbrooke, QB', 'Trois-Rivieres, QB',
#        'Montreal, QB'],
#       dtype='object', name='Police Jurisdiction')

# %%
maritimes = list(data.columns[0:4])
quebec = list(data.columns[4:10])
ontario = list(data.columns[10:24])
praries = list(data.columns[24:30])
bc = list(data.columns[30:])

# %%
data[maritimes].plot(figsize=(10, 8))

# %%
data[quebec].plot(figsize=(10, 8), title='Quebec')

# %%
data[ontario].plot(figsize=(10, 8), title='Ontario')

# %%
data[praries].plot(figsize=(10, 8), title='Praries')

# %%
data[bc].plot(figsize=(10, 8), title='BC')
